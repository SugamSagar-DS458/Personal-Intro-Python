# %%
name = input("What is your name? ") # input name by user
age = input("How old are you? ") # inpute age by user
hobby = input("What is your favorite hobby? ") # input hobby of the user

print(f"\n🎉 Welcome {name}! 🎉")
print(f"You are {age} years old and love {hobby}.")
# Out:
# What is your name?  Sugam Sagar
# How old are you?  31
# What is your favorite hobby?  Playing Games
# 🎉 Welcome Sugam Sagar! 🎉
# You are 31 years old and love Playing Games.
